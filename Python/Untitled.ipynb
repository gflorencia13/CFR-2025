# %% [markdown]
# count vowels in "Hello World"

# %%
def vowels (a, i, e, u, o):
    how_many_vowels = "Hello World"
    return how_many_vowels

# Call the function
vowels
# Out:
#   Cell In[2], line 2
#     how_many_vowels = Hello World
#                             ^
# SyntaxError: invalid syntax

# %%
def vowels (text):
    count = 0
